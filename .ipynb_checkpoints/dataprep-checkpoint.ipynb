# %%
import pandas as pd
import numpy as np
import requests

# %%
df_stream = pd.read_json(r'C:\Users\ROG\Desktop\Project\my_spotify_data\MyData\StreamingHistory.json')
df_stream['UniqueID'] = df_stream['master_metadata_album_artist_name'] + ":" + df_stream['master_metadata_track_name']
df_stream.head()
# Out:
#                      ts                   username  \
# 0  2022-02-19T10:02:48Z  ozdakaac3d5c3izl7tcrrzu7i
# 1  2022-02-19T10:02:50Z  ozdakaac3d5c3izl7tcrrzu7i
# 2  2022-02-19T10:02:53Z  ozdakaac3d5c3izl7tcrrzu7i
# 3  2022-02-19T10:05:25Z  ozdakaac3d5c3izl7tcrrzu7i
# 4  2022-02-19T10:05:29Z  ozdakaac3d5c3izl7tcrrzu7i
#
#                        platform  ms_played conn_country ip_addr_decrypted  \
# 0  Windows 10 (10.0.19043; x64)     219226           IN    106.215.84.189
# 1  Windows 10 (10.0.19043; x64)       2800           IN    106.215.84.189
# 2  Windows 10 (10.0.19043; x64)       2260           IN    106.215.84.189
# 3  Windows 10 (10.0.19043; x64)     153190           IN    106.215.84.189
# 4  Windows 10 (10.0.19043; x64)       2079           IN    106.215.84.189
#
#   user_agent_decrypted master_metadata_track_name  \
# 0              unknown                       IDOL
# 1              unknown                      Ghost
# 2              unknown                    deja vu
# 3              unknown                      Ghost
# 4              unknown                    deja vu
#
#   master_metadata_album_artist_name master_metadata_album_album_name  ...  \
# 0                               BTS         Love Yourself 結 'Answer'  ...
# 1                     Justin Bieber                          Justice  ...
# 2                    Olivia Rodrigo                             SOUR  ...
# 3                     Justin Bieber                          Justice  ...
# 4                    Olivia Rodrigo                             SOUR  ...
#
#   episode_show_name spotify_episode_uri reason_start reason_end shuffle  \
# 0              None                None    trackdone     fwdbtn   False
# 1              None                None       fwdbtn     fwdbtn   False
# 2              None                None       fwdbtn    backbtn   False
# 3              None                None      backbtn  trackdone   False
# 4              None                None    trackdone     fwdbtn   False
#
#   skipped  offline  offline_timestamp  incognito_mode                UniqueID
# 0     NaN    False      1645264745973            True                BTS:IDOL
# 1     NaN    False      1645264966593            True     Justin Bieber:Ghost
# 2     NaN    False      1645264969534            True  Olivia Rodrigo:deja vu
# 3     NaN    False      1645264971917            True     Justin Bieber:Ghost
# 4     NaN    False      1645265124244            True  Olivia Rodrigo:deja vu
#
# [5 rows x 22 columns]

# %%
new = df_stream["spotify_track_uri"].str.split(":", expand = True)
df_stream['track_uri'] = new[2]

# %%
df_stream.head()
# Out:
#                      ts                   username  \
# 0  2022-02-19T10:02:48Z  ozdakaac3d5c3izl7tcrrzu7i
# 1  2022-02-19T10:02:50Z  ozdakaac3d5c3izl7tcrrzu7i
# 2  2022-02-19T10:02:53Z  ozdakaac3d5c3izl7tcrrzu7i
# 3  2022-02-19T10:05:25Z  ozdakaac3d5c3izl7tcrrzu7i
# 4  2022-02-19T10:05:29Z  ozdakaac3d5c3izl7tcrrzu7i
#
#                        platform  ms_played conn_country ip_addr_decrypted  \
# 0  Windows 10 (10.0.19043; x64)     219226           IN    106.215.84.189
# 1  Windows 10 (10.0.19043; x64)       2800           IN    106.215.84.189
# 2  Windows 10 (10.0.19043; x64)       2260           IN    106.215.84.189
# 3  Windows 10 (10.0.19043; x64)     153190           IN    106.215.84.189
# 4  Windows 10 (10.0.19043; x64)       2079           IN    106.215.84.189
#
#   user_agent_decrypted master_metadata_track_name  \
# 0              unknown                       IDOL
# 1              unknown                      Ghost
# 2              unknown                    deja vu
# 3              unknown                      Ghost
# 4              unknown                    deja vu
#
#   master_metadata_album_artist_name master_metadata_album_album_name  ...  \
# 0                               BTS         Love Yourself 結 'Answer'  ...
# 1                     Justin Bieber                          Justice  ...
# 2                    Olivia Rodrigo                             SOUR  ...
# 3                     Justin Bieber                          Justice  ...
# 4                    Olivia Rodrigo                             SOUR  ...
#
#   spotify_episode_uri reason_start reason_end shuffle skipped offline  \
# 0                None    trackdone     fwdbtn   False     NaN   False
# 1                None       fwdbtn     fwdbtn   False     NaN   False
# 2                None       fwdbtn    backbtn   False     NaN   False
# 3                None      backbtn  trackdone   False     NaN   False
# 4                None    trackdone     fwdbtn   False     NaN   False
#
#    offline_timestamp  incognito_mode                UniqueID  \
# 0      1645264745973            True                BTS:IDOL
# 1      1645264966593            True     Justin Bieber:Ghost
# 2      1645264969534            True  Olivia Rodrigo:deja vu
# 3      1645264971917            True     Justin Bieber:Ghost
# 4      1645265124244            True  Olivia Rodrigo:deja vu
#
#                 track_uri
# 0  1e8J3XClxZbFmvIHLI8CE4
# 1  6I3mqTwhRpn34SLVafSH7G
# 2  6HU7h9RYOaPRFeh0R3UeAr
# 3  6I3mqTwhRpn34SLVafSH7G
# 4  6HU7h9RYOaPRFeh0R3UeAr
#
# [5 rows x 23 columns]

# %%
df_tableau = df_stream.copy()

# %%
df_tableau.drop('ts',
  axis='columns', inplace=True)

# %%
df_tableau.drop(['platform','ms_played','conn_country','ip_addr_decrypted','user_agent_decrypted','spotify_episode_uri','reason_start','reason_end','shuffle','skipped','offline','offline_timestamp','incognito_mode'],axis='columns', inplace=True)

# %%
df_tableau.drop(['episode_name','episode_show_name'],axis='columns', inplace=True)

# %%
df_tableau.head()
# Out:
#                     username master_metadata_track_name  \
# 0  ozdakaac3d5c3izl7tcrrzu7i                       IDOL
# 1  ozdakaac3d5c3izl7tcrrzu7i                      Ghost
# 2  ozdakaac3d5c3izl7tcrrzu7i                    deja vu
# 3  ozdakaac3d5c3izl7tcrrzu7i                      Ghost
# 4  ozdakaac3d5c3izl7tcrrzu7i                    deja vu
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                               BTS         Love Yourself 結 'Answer'
# 1                     Justin Bieber                          Justice
# 2                    Olivia Rodrigo                             SOUR
# 3                     Justin Bieber                          Justice
# 4                    Olivia Rodrigo                             SOUR
#
#                       spotify_track_uri                UniqueID  \
# 0  spotify:track:1e8J3XClxZbFmvIHLI8CE4                BTS:IDOL
# 1  spotify:track:6I3mqTwhRpn34SLVafSH7G     Justin Bieber:Ghost
# 2  spotify:track:6HU7h9RYOaPRFeh0R3UeAr  Olivia Rodrigo:deja vu
# 3  spotify:track:6I3mqTwhRpn34SLVafSH7G     Justin Bieber:Ghost
# 4  spotify:track:6HU7h9RYOaPRFeh0R3UeAr  Olivia Rodrigo:deja vu
#
#                 track_uri
# 0  1e8J3XClxZbFmvIHLI8CE4
# 1  6I3mqTwhRpn34SLVafSH7G
# 2  6HU7h9RYOaPRFeh0R3UeAr
# 3  6I3mqTwhRpn34SLVafSH7G
# 4  6HU7h9RYOaPRFeh0R3UeAr

# %%
CLIENT_ID = '49d5708ae93e44cc98d01a16a5f4677b'
CLIENT_SECRET = '8de6296d292e4002bd895bba2f5e8d35'

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
headers = {'Authorization': 'Bearer {token}'.format(token=access_token)}
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# %%
dict_genre = {}

track_uris = df_stream['track_uri'].to_list()

for t_uri in track_uris:
    
    dict_genre[t_uri] = {'artist_uri': "", "genres":[]}
    
    r = requests.get(f"https://api.spotify.com/v1/tracks/{t_uri}", headers=headers)
    r=r.json()
    a_uri = r['artists'][0]['uri'].split(':')[2]
    dict_genre[t_uri]['artist_uri'] = a_uri
    
    s = requests.get(f"https://api.spotify.com/v1/artists/{a_uri}", headers=headers)
    s = s.json()
    dict_genre[t_uri]['genres'] = s['genres']
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\models.py:960, in Response.json(self, **kwargs)
#     959 try:
# --> 960     return complexjson.loads(self.content.decode(encoding), **kwargs)
#     961 except UnicodeDecodeError:
#     962     # Wrong UTF codec detected; usually because it's not UTF-8
#     963     # but some other 8-bit codec.  This is an RFC violation,
#     964     # and the server didn't bother to tell us what codec *was*
#     965     # used.
#
# File ~\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\anaconda3\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[52], line 10
#       7 dict_genre[t_uri] = {'artist_uri': "", "genres":[]}
#       9 r = requests.get(f"https://api.spotify.com/v1/tracks/{t_uri}", headers=headers)
# ---> 10 r=r.json()
#      11 a_uri = r['artists'][0]['uri'].split(':')[2]
#      12 dict_genre[t_uri]['artist_uri'] = a_uri
#
# File ~\anaconda3\lib\site-packages\requests\models.py:968, in Response.json(self, **kwargs)
#     966             pass
#     967         except JSONDecodeError as e:
# --> 968             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     970 try:
#     971     return complexjson.loads(self.text, **kwargs)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df_tableau.to_csv('MySpotifyDataTable.csv')

# %%
df_genre = pd.DataFrame.from_dict(dict_genre, orient='index')
df_genre.insert(0, 'track_uri', df_genre.index)
df_genre.reset_index(inplace=True, drop=True)

df_genre.head()
